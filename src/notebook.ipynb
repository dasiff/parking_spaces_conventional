# %%
from PIL import Image
image_path = r"G:\My Drive\parking_spaces\data\raw_images\Mta_Company_9400_N_Central_Expy_Dallas_TX_75231_0800_United_States.png"

img = Image.open(image_path)
print(img.info)
# Out:
# {}
